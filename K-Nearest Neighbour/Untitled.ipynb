# %%
'''
Classifier using K-Nearest Neighbour algorithm
for Iris Flower Dataset
'''
import numpy as np
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()

print(iris.feature_names)
print(iris.target_names)

for i in range(len(iris.target)):
    print("Example {}: Features: {}, Labels: {}" \
    .format(i, iris.data[i], iris.target[i]))

test_idx = [0, 50, 100]

# training data
train_target = np.delete(iris.target, test_idx)
train_data = np.delete(iris.data, test_idx, axis=0)

# testing data
test_target = iris.target[test_idx]
test_data = iris.data[test_idx]

knn = KNeighborsClassifier()
knn.fit(train_data, train_target)

print("\nTest data:\n %s" %test_data)
print("\nTest target: %s" %test_target)
print("\nPredicted target: %s\n" %knn.predict(test_data))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# Example 0: Features: [ 5.1  3.5  1.4  0.2], Labels: 0
# Example 1: Features: [ 4.9  3.   1.4  0.2], Labels: 0
# Example 2: Features: [ 4.7  3.2  1.3  0.2], Labels: 0
# Example 3: Features: [ 4.6  3.1  1.5  0.2], Labels: 0
# Example 4: Features: [ 5.   3.6  1.4  0.2], Labels: 0
# Example 5: Features: [ 5.4  3.9  1.7  0.4], Labels: 0
# Example 6: Features: [ 4.6  3.4  1.4  0.3], Labels: 0
# Example 7: Features: [ 5.   3.4  1.5  0.2], Labels: 0
# Example 8: Features: [ 4.4  2.9  1.4  0.2], Labels: 0
# Example 9: Features: [ 4.9  3.1  1.5  0.1], Labels: 0
# Example 10: Features: [ 5.4  3.7  1.5  0.2], Labels: 0
# Example 11: Features: [ 4.8  3.4  1.6  0.2], Labels: 0
# Example 12: Features: [ 4.8  3.   1.4  0.1], Labels: 0
# Example 13: Features: [ 4.3  3.   1.1  0.1], Labels: 0
# Example 14: Features: [ 5.8  4.   1.2  0.2], Labels: 0
# Example 15: Features: [ 5.7  4.4  1.5  0.4], Labels: 0
# Example 16: Features: [ 5.4  3.9  1.3  0.4], Labels: 0
# Example 17: Features: [ 5.1  3.5  1.4  0.3], Labels: 0
# Example 18: Features: [ 5.7  3.8  1.7  0.3], Labels: 0
# Example 19: Features: [ 5.1  3.8  1.5  0.3], Labels: 0
# Example 20: Features: [ 5.4  3.4  1.7  0.2], Labels: 0
# Example 21: Features: [ 5.1  3.7  1.5  0.4], Labels: 0
# Example 22: Features: [ 4.6  3.6  1.   0.2], Labels: 0
# Example 23: Features: [ 5.1  3.3  1.7  0.5], Labels: 0
# Example 24: Features: [ 4.8  3.4  1.9  0.2], Labels: 0
# Example 25: Features: [ 5.   3.   1.6  0.2], Labels: 0
# Example 26: Features: [ 5.   3.4  1.6  0.4], Labels: 0
# Example 27: Features: [ 5.2  3.5  1.5  0.2], Labels: 0
# Example 28: Features: [ 5.2  3.4  1.4  0.2], Labels: 0
# Example 29: Features: [ 4.7  3.2  1.6  0.2], Labels: 0
# Example 30: Features: [ 4.8  3.1  1.6  0.2], Labels: 0
# Example 31: Features: [ 5.4  3.4  1.5  0.4], Labels: 0
# Example 32: Features: [ 5.2  4.1  1.5  0.1], Labels: 0
# Example 33: Features: [ 5.5  4.2  1.4  0.2], Labels: 0
# Example 34: Features: [ 4.9  3.1  1.5  0.1], Labels: 0
# Example 35: Features: [ 5.   3.2  1.2  0.2], Labels: 0
# Example 36: Features: [ 5.5  3.5  1.3  0.2], Labels: 0
# Example 37: Features: [ 4.9  3.1  1.5  0.1], Labels: 0
# Example 38: Features: [ 4.4  3.   1.3  0.2], Labels: 0
# Example 39: Features: [ 5.1  3.4  1.5  0.2], Labels: 0
# Example 40: Features: [ 5.   3.5  1.3  0.3], Labels: 0
# Example 41: Features: [ 4.5  2.3  1.3  0.3], Labels: 0
# Example 42: Features: [ 4.4  3.2  1.3  0.2], Labels: 0
# Example 43: Features: [ 5.   3.5  1.6  0.6], Labels: 0
# Example 44: Features: [ 5.1  3.8  1.9  0.4], Labels: 0
# Example 45: Features: [ 4.8  3.   1.4  0.3], Labels: 0
# Example 46: Features: [ 5.1  3.8  1.6  0.2], Labels: 0
# Example 47: Features: [ 4.6  3.2  1.4  0.2], Labels: 0
# Example 48: Features: [ 5.3  3.7  1.5  0.2], Labels: 0
# Example 49: Features: [ 5.   3.3  1.4  0.2], Labels: 0
# Example 50: Features: [ 7.   3.2  4.7  1.4], Labels: 1
# Example 51: Features: [ 6.4  3.2  4.5  1.5], Labels: 1
# Example 52: Features: [ 6.9  3.1  4.9  1.5], Labels: 1
# Example 53: Features: [ 5.5  2.3  4.   1.3], Labels: 1
# Example 54: Features: [ 6.5  2.8  4.6  1.5], Labels: 1
# Example 55: Features: [ 5.7  2.8  4.5  1.3], Labels: 1
# Example 56: Features: [ 6.3  3.3  4.7  1.6], Labels: 1
# Example 57: Features: [ 4.9  2.4  3.3  1. ], Labels: 1
# Example 58: Features: [ 6.6  2.9  4.6  1.3], Labels: 1
# Example 59: Features: [ 5.2  2.7  3.9  1.4], Labels: 1
# Example 60: Features: [ 5.   2.   3.5  1. ], Labels: 1
# Example 61: Features: [ 5.9  3.   4.2  1.5], Labels: 1
# Example 62: Features: [ 6.   2.2  4.   1. ], Labels: 1
# Example 63: Features: [ 6.1  2.9  4.7  1.4], Labels: 1
# Example 64: Features: [ 5.6  2.9  3.6  1.3], Labels: 1
# Example 65: Features: [ 6.7  3.1  4.4  1.4], Labels: 1
# Example 66: Features: [ 5.6  3.   4.5  1.5], Labels: 1
# Example 67: Features: [ 5.8  2.7  4.1  1. ], Labels: 1
# Example 68: Features: [ 6.2  2.2  4.5  1.5], Labels: 1
# Example 69: Features: [ 5.6  2.5  3.9  1.1], Labels: 1
# Example 70: Features: [ 5.9  3.2  4.8  1.8], Labels: 1
# Example 71: Features: [ 6.1  2.8  4.   1.3], Labels: 1
# Example 72: Features: [ 6.3  2.5  4.9  1.5], Labels: 1
# Example 73: Features: [ 6.1  2.8  4.7  1.2], Labels: 1
# Example 74: Features: [ 6.4  2.9  4.3  1.3], Labels: 1
# Example 75: Features: [ 6.6  3.   4.4  1.4], Labels: 1
# Example 76: Features: [ 6.8  2.8  4.8  1.4], Labels: 1
# Example 77: Features: [ 6.7  3.   5.   1.7], Labels: 1
# Example 78: Features: [ 6.   2.9  4.5  1.5], Labels: 1
# Example 79: Features: [ 5.7  2.6  3.5  1. ], Labels: 1
# Example 80: Features: [ 5.5  2.4  3.8  1.1], Labels: 1
# Example 81: Features: [ 5.5  2.4  3.7  1. ], Labels: 1
# Example 82: Features: [ 5.8  2.7  3.9  1.2], Labels: 1
# Example 83: Features: [ 6.   2.7  5.1  1.6], Labels: 1
# Example 84: Features: [ 5.4  3.   4.5  1.5], Labels: 1
# Example 85: Features: [ 6.   3.4  4.5  1.6], Labels: 1
# Example 86: Features: [ 6.7  3.1  4.7  1.5], Labels: 1
# Example 87: Features: [ 6.3  2.3  4.4  1.3], Labels: 1
# Example 88: Features: [ 5.6  3.   4.1  1.3], Labels: 1
# Example 89: Features: [ 5.5  2.5  4.   1.3], Labels: 1
# Example 90: Features: [ 5.5  2.6  4.4  1.2], Labels: 1
# Example 91: Features: [ 6.1  3.   4.6  1.4], Labels: 1
# Example 92: Features: [ 5.8  2.6  4.   1.2], Labels: 1
# Example 93: Features: [ 5.   2.3  3.3  1. ], Labels: 1
# Example 94: Features: [ 5.6  2.7  4.2  1.3], Labels: 1
# Example 95: Features: [ 5.7  3.   4.2  1.2], Labels: 1
# Example 96: Features: [ 5.7  2.9  4.2  1.3], Labels: 1
# Example 97: Features: [ 6.2  2.9  4.3  1.3], Labels: 1
# Example 98: Features: [ 5.1  2.5  3.   1.1], Labels: 1
# Example 99: Features: [ 5.7  2.8  4.1  1.3], Labels: 1
# Example 100: Features: [ 6.3  3.3  6.   2.5], Labels: 2
# Example 101: Features: [ 5.8  2.7  5.1  1.9], Labels: 2
# Example 102: Features: [ 7.1  3.   5.9  2.1], Labels: 2
# Example 103: Features: [ 6.3  2.9  5.6  1.8], Labels: 2
# Example 104: Features: [ 6.5  3.   5.8  2.2], Labels: 2
# Example 105: Features: [ 7.6  3.   6.6  2.1], Labels: 2
# Example 106: Features: [ 4.9  2.5  4.5  1.7], Labels: 2
# Example 107: Features: [ 7.3  2.9  6.3  1.8], Labels: 2
# Example 108: Features: [ 6.7  2.5  5.8  1.8], Labels: 2
# Example 109: Features: [ 7.2  3.6  6.1  2.5], Labels: 2
# Example 110: Features: [ 6.5  3.2  5.1  2. ], Labels: 2
# Example 111: Features: [ 6.4  2.7  5.3  1.9], Labels: 2
# Example 112: Features: [ 6.8  3.   5.5  2.1], Labels: 2
# Example 113: Features: [ 5.7  2.5  5.   2. ], Labels: 2
# Example 114: Features: [ 5.8  2.8  5.1  2.4], Labels: 2
# Example 115: Features: [ 6.4  3.2  5.3  2.3], Labels: 2
# Example 116: Features: [ 6.5  3.   5.5  1.8], Labels: 2
# Example 117: Features: [ 7.7  3.8  6.7  2.2], Labels: 2
# Example 118: Features: [ 7.7  2.6  6.9  2.3], Labels: 2
# Example 119: Features: [ 6.   2.2  5.   1.5], Labels: 2
# Example 120: Features: [ 6.9  3.2  5.7  2.3], Labels: 2
# Example 121: Features: [ 5.6  2.8  4.9  2. ], Labels: 2
# Example 122: Features: [ 7.7  2.8  6.7  2. ], Labels: 2
# Example 123: Features: [ 6.3  2.7  4.9  1.8], Labels: 2
# Example 124: Features: [ 6.7  3.3  5.7  2.1], Labels: 2
# Example 125: Features: [ 7.2  3.2  6.   1.8], Labels: 2
# Example 126: Features: [ 6.2  2.8  4.8  1.8], Labels: 2
# Example 127: Features: [ 6.1  3.   4.9  1.8], Labels: 2
# Example 128: Features: [ 6.4  2.8  5.6  2.1], Labels: 2
# Example 129: Features: [ 7.2  3.   5.8  1.6], Labels: 2
# Example 130: Features: [ 7.4  2.8  6.1  1.9], Labels: 2
# Example 131: Features: [ 7.9  3.8  6.4  2. ], Labels: 2
# Example 132: Features: [ 6.4  2.8  5.6  2.2], Labels: 2
# Example 133: Features: [ 6.3  2.8  5.1  1.5], Labels: 2
# Example 134: Features: [ 6.1  2.6  5.6  1.4], Labels: 2
# Example 135: Features: [ 7.7  3.   6.1  2.3], Labels: 2
# Example 136: Features: [ 6.3  3.4  5.6  2.4], Labels: 2
# Example 137: Features: [ 6.4  3.1  5.5  1.8], Labels: 2
# Example 138: Features: [ 6.   3.   4.8  1.8], Labels: 2
# Example 139: Features: [ 6.9  3.1  5.4  2.1], Labels: 2
# Example 140: Features: [ 6.7  3.1  5.6  2.4], Labels: 2
# Example 141: Features: [ 6.9  3.1  5.1  2.3], Labels: 2
# Example 142: Features: [ 5.8  2.7  5.1  1.9], Labels: 2
# Example 143: Features: [ 6.8  3.2  5.9  2.3], Labels: 2
# Example 144: Features: [ 6.7  3.3  5.7  2.5], Labels: 2
# Example 145: Features: [ 6.7  3.   5.2  2.3], Labels: 2
# Example 146: Features: [ 6.3  2.5  5.   1.9], Labels: 2
# Example 147: Features: [ 6.5  3.   5.2  2. ], Labels: 2
# Example 148: Features: [ 6.2  3.4  5.4  2.3], Labels: 2
# Example 149: Features: [ 5.9  3.   5.1  1.8], Labels: 2
#
# Test data:
#  [[ 5.1  3.5  1.4  0.2]
#  [ 7.   3.2  4.7  1.4]
#  [ 6.3  3.3  6.   2.5]]
#
# Test target: [0 1 2]
#
# Predicted target: [0 1 2]
